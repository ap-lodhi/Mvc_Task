-- %% [markdown]
-- # [dbo].[college_admission_master]

-- %%
USE [college_Master]
GO

-- %%
/****** Object:  Table [dbo].[college_admission_master]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[college_admission_master](
	[collage_id] [int] NOT NULL,
	[clg_name] [varchar](255) NOT NULL,
	[session] [varchar](10) NOT NULL,
	[admission_date] [datetime] NULL,
	[collage_fees] [decimal](10, 2) NULL,
	[clg_payment] [bit] NULL,
	[is_active] [bit] NULL,
	[created_date] [datetime] NULL,
	[student_id] [int] NULL,
	[role_id] [int] NULL,
	[department_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[collage_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[College_Master]

-- %%
/****** Object:  Table [dbo].[College_Master]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[College_Master](
	[clg_id] [int] IDENTITY(1,1) NOT NULL,
	[collegeName] [varchar](50) NULL,
	[StudenName] [int] NULL,
	[branchName] [int] NULL,
	[RoleDesignation] [int] NULL,
	[fees] [decimal](18, 2) NULL,
	[AddmissionDate] [datetime] NULL,
	[Is_Payment] [bit] NULL,
	[Is_active] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[clg_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[department_master]

-- %%
/****** Object:  Table [dbo].[department_master]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[department_master](
	[Branch_id] [int] IDENTITY(1,1) NOT NULL,
	[Branch_name] [varchar](255) NOT NULL,
	[Hod_name] [varchar](255) NULL,
	[created_date] [date] NULL,
	[Is_active] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Branch_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Role_master]

-- %%
/****** Object:  Table [dbo].[Role_master]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Role_master](
	[Role_id] [int] IDENTITY(1,1) NOT NULL,
	[Role_name] [varchar](255) NOT NULL,
	[Role_designation] [varchar](255) NULL,
	[created_date] [date] NULL,
	[Is_active] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Role_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Student]

-- %%
/****** Object:  Table [dbo].[Student]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Student](
	[Name] [varchar](100) NULL,
	[DOB] [varchar](100) NULL,
	[Age] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[student_master]

-- %%
/****** Object:  Table [dbo].[student_master]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[student_master](
	[Student_id] [int] IDENTITY(1,1) NOT NULL,
	[Student_fisrt_Name] [varchar](255) NOT NULL,
	[Student_Last_Name] [varchar](255) NULL,
	[Student_Email] [varchar](255) NULL,
	[Student_Phone] [varchar](20) NULL,
	[Student_Session] [varchar](255) NULL,
	[created_date] [datetime] NULL,
	[Is_active] [bit] NULL,
	[Is_Deleted] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Student_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_signup]

-- %%
/****** Object:  Table [dbo].[tbl_signup]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_signup](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NULL,
	[emailId] [nvarchar](50) NULL,
	[encryptedPassword] [nvarchar](50) NULL,
	[decryptedPassword] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__college_a__creat__3B0BC30C]

-- %%
ALTER TABLE [dbo].[college_admission_master] ADD  DEFAULT (getdate()) FOR [created_date]
GO

-- %% [markdown]
-- # [FK__college_a__depar__3DE82FB7]

-- %%
ALTER TABLE [dbo].[college_admission_master]  WITH CHECK ADD FOREIGN KEY([department_id])
REFERENCES [dbo].[department_master] ([Branch_id])
GO

-- %% [markdown]
-- # [FK__college_a__role___3CF40B7E]

-- %%
ALTER TABLE [dbo].[college_admission_master]  WITH CHECK ADD FOREIGN KEY([role_id])
REFERENCES [dbo].[Role_master] ([Role_id])
GO

-- %% [markdown]
-- # [FK__college_a__stude__3BFFE745]

-- %%
ALTER TABLE [dbo].[college_admission_master]  WITH CHECK ADD FOREIGN KEY([student_id])
REFERENCES [dbo].[student_master] ([Student_id])
GO

-- %% [markdown]
-- # [FK__College_M__branc__345EC57D]

-- %%
ALTER TABLE [dbo].[College_Master]  WITH CHECK ADD FOREIGN KEY([branchName])
REFERENCES [dbo].[department_master] ([Branch_id])
GO

-- %% [markdown]
-- # [FK__College_M__RoleD__3552E9B6]

-- %%
ALTER TABLE [dbo].[College_Master]  WITH CHECK ADD FOREIGN KEY([RoleDesignation])
REFERENCES [dbo].[Role_master] ([Role_id])
GO

-- %% [markdown]
-- # [FK__College_M__Stude__336AA144]

-- %%
ALTER TABLE [dbo].[College_Master]  WITH CHECK ADD FOREIGN KEY([StudenName])
REFERENCES [dbo].[student_master] ([Student_id])
GO

-- %% [markdown]
-- # [dbo].[GeSearchDateCollegeDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[GeSearchDateCollegeDetails]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[GeSearchDateCollegeDetails]
    @fromDate DATE = NULL,
    @toDate DATE = NULL
AS
BEGIN
    SELECT
        cm.clg_id,
        cm.collegeName,
        cm.fees,
        cm.AddmissionDate,
        cm.Is_Payment,
        cm.Is_active,
        rm.Role_designation,
        dm.Branch_name,
        sm.Student_fisrt_Name
    FROM
        College_Master cm
    INNER JOIN
        Role_master rm ON cm.RoleDesignation = rm.Role_id
    INNER JOIN
        department_master dm ON cm.branchName = dm.Branch_id
    INNER JOIN
        student_master sm ON cm.StudenName = sm.Student_id
    WHERE
        (@fromDate IS NULL OR cm.AddmissionDate >= @fromDate)
        AND (@toDate IS NULL OR cm.AddmissionDate <= @toDate);
END;
GO

-- %% [markdown]
-- # [dbo].[GetCollegeFilteredData]

-- %%
/****** Object:  StoredProcedure [dbo].[GetCollegeFilteredData]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetCollegeFilteredData]
    @fromDate DATE = NULL,
    @toDate DATE = NULL
AS
BEGIN
    SELECT
        cm.clg_id,
        cm.collegeName,
        cm.fees,
        cm.AddmissionDate,
        cm.Is_Payment,
        cm.Is_active,
        rm.Role_designation,
        dm.Branch_name,
        sm.Student_fisrt_Name
    FROM
        College_Master cm
    INNER JOIN
        Role_master rm ON cm.RoleDesignation = rm.Role_id
    INNER JOIN
        department_master dm ON cm.branchName = dm.Branch_id
    INNER JOIN
        student_master sm ON cm.StudenName = sm.Student_id
    WHERE
        cm.AddmissionDate >= CASE WHEN @fromDate IS NULL THEN cm.AddmissionDate ELSE @fromDate END
        AND cm.AddmissionDate <= CASE WHEN @toDate IS NULL THEN cm.AddmissionDate ELSE @toDate END;
END;
GO

-- %% [markdown]
-- # [dbo].[GetCollegeMasterDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[GetCollegeMasterDetails]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

	CREATE PROCEDURE [dbo].[GetCollegeMasterDetails]
AS
BEGIN
    SELECT
        cm.clg_id,
        cm.collegeName,
        cm.fees,
        cm.AddmissionDate,
        cm.Is_Payment,
        cm.Is_active,
        rm.Role_designation,
        dm.Branch_name,
        sm.Student_fisrt_Name
    FROM
        College_Master cm
    INNER JOIN
        Role_master rm ON cm.RoleDesignation = rm.Role_id
    INNER JOIN
        department_master dm ON cm.branchName = dm.Branch_id
    INNER JOIN
        student_master sm ON cm.StudenName = sm.Student_id;
END;

GO

-- %% [markdown]
-- # [dbo].[GetDepartmentList]

-- %%
/****** Object:  StoredProcedure [dbo].[GetDepartmentList]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create  PROCEDURE [dbo].[GetDepartmentList]
   
AS
BEGIN
 SELECT * FROM department_master
END;
GO

-- %% [markdown]
-- # [dbo].[GetRoleUser]

-- %%
/****** Object:  StoredProcedure [dbo].[GetRoleUser]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create  PROCEDURE [dbo].[GetRoleUser]
   
AS
BEGIN
  SELECT * FROM Role_master
END;
GO

-- %% [markdown]
-- # [dbo].[Insert_Student]

-- %%
/****** Object:  StoredProcedure [dbo].[Insert_Student]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[Insert_Student]
    @Name VARCHAR(100),
    @DOB varchar(100),
    @Age INT
AS
BEGIN
    INSERT INTO Student (Name, DOB, Age)
    VALUES (@Name, @DOB, @Age)
END
GO

-- %% [markdown]
-- # [dbo].[InsertDeparmentUser]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertDeparmentUser]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[InsertDeparmentUser]
    @Branch_name VARCHAR(255) ,
   @Hod_name VARCHAR(255),
	 @created_date date,
    @Is_active BIT
AS
BEGIN
    INSERT INTO department_master (Branch_name, Hod_name, created_date, Is_active)
    VALUES (@Branch_name, @Hod_name, @created_date, @Is_active);
END;
GO

-- %% [markdown]
-- # [dbo].[InsertEmployee]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertEmployee]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertEmployee]
    @Name NVARCHAR(255),
    @Role NVARCHAR(100),
    @Salary NVARCHAR(100)
AS
BEGIN
    INSERT INTO Employee (Name, Role, Salary)
    VALUES (@Name, @Role, @Salary);
END;
GO

-- %% [markdown]
-- # [dbo].[InsertEmployeesssss]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertEmployeesssss]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[InsertEmployeesssss]
    @Name NVARCHAR(255),
    @Role NVARCHAR(100),
    @Salary NVARCHAR(100)
AS
BEGIN
    INSERT INTO Employee_Tbl23 (Name, Role, Salary)
    VALUES (@Name, @Role, @Salary);
END;
GO

-- %% [markdown]
-- # [dbo].[InsertRoleUser]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertRoleUser]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertRoleUser]
    @Role_name VARCHAR(255),
    @Role_designation VARCHAR(255),
	 @created_date date,
    @Is_active BIT
AS
BEGIN
    INSERT INTO Role_master (Role_name, Role_designation, created_date, Is_active)
    VALUES (@Role_name, @Role_designation, @created_date, @Is_active);
END;
GO

-- %% [markdown]
-- # [dbo].[RegisterUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[RegisterUsers]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[RegisterUsers]
    @name NVARCHAR(50),
     @emailId NVARCHAR(50),
    @encryptedPassword NVARCHAR(50),
    @decryptedPassword NVARCHAR(50)
AS
BEGIN
    INSERT INTO tbl_signup (name, emailId, encryptedPassword, decryptedPassword)
    VALUES (@name, @emailId, @encryptedPassword, @decryptedPassword);
END;
GO

-- %% [markdown]
-- # [dbo].[sp_delete_college_Details]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_delete_college_Details]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_delete_college_Details]
   @id int
AS
BEGIN
 delete from  College_Master where clg_id = @id
       
END;
GO

-- %% [markdown]
-- # [dbo].[sp_deleteDepMasterItem]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_deleteDepMasterItem]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  PROCEDURE [dbo].[sp_deleteDepMasterItem]
    @id INT
AS
BEGIN
   delete  from department_master where Branch_id=@id
END;
GO

-- %% [markdown]
-- # [dbo].[sp_deleteRoleMasterItem]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_deleteRoleMasterItem]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  PROCEDURE [dbo].[sp_deleteRoleMasterItem]
    @id INT
AS
BEGIN
   delete  from Role_master where Role_id=@id
END;
GO

-- %% [markdown]
-- # [dbo].[sp_deleteStudentMasterItem]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_deleteStudentMasterItem]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  PROCEDURE [dbo].[sp_deleteStudentMasterItem]
    @id INT
AS
BEGIN
   delete  from student_master where Student_id=@id
END;
GO

-- %% [markdown]
-- # [dbo].[sp_getAllStudentDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_getAllStudentDetails]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  PROCEDURE [dbo].[sp_getAllStudentDetails]
 
AS
BEGIN
  select * from student_master
END;
GO

-- %% [markdown]
-- # [dbo].[sp_GetCollegeDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetCollegeDetailsById]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_GetCollegeDetailsById]
   @clg_id INT
AS
BEGIN
   SELECT
      College_Master.clg_id,
      College_Master.collegeName,
      College_Master.fees,
      College_Master.AddmissionDate,
      College_Master.Is_Payment,
      College_Master.Is_active,
      Role_master.Role_designation,
      department_master.Branch_name,
      student_master.Student_fisrt_Name
   FROM
      College_Master
   INNER JOIN
      Role_master ON College_Master.RoleDesignation = Role_master.Role_id
   INNER JOIN
      department_master ON College_Master.branchName = department_master.Branch_id
   INNER JOIN
      student_master ON College_Master.StudenName = student_master.Student_id
   WHERE
      College_Master.clg_id = @clg_id;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_GetDepartmentListById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetDepartmentListById]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  PROCEDURE [dbo].[sp_GetDepartmentListById]
    @id INT
AS
BEGIN
   select * from department_master where Branch_id= @id
END;
GO

-- %% [markdown]
-- # [dbo].[sp_GetRoleListById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetRoleListById]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  PROCEDURE [dbo].[sp_GetRoleListById]
    @id INT
AS
BEGIN
   select * from Role_master where Role_id=@id
END;
GO

-- %% [markdown]
-- # [dbo].[sp_GetStudentListById]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetStudentListById]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  PROCEDURE [dbo].[sp_GetStudentListById]
    @id INT
AS
BEGIN
   select * from student_master where Student_id= @id
END;
GO

-- %% [markdown]
-- # [dbo].[sp_insert_college_Details]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_insert_college_Details]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_insert_college_Details]
    @CollegeName VARCHAR(50),
    @StudenName INT,
    @branchName INT,
    @RoleDesignation INT,
    @Fees DECIMAL(18, 2),
    @AdmissionDate DATETIME,
    @IsPayment BIT,
    @IsActive BIT
AS
BEGIN
    INSERT INTO College_Master (
        collegeName,
        StudenName,
        branchName,
        RoleDesignation,
        fees,
        AddmissionDate,
        Is_Payment,
        Is_active
    )
    VALUES (
        @CollegeName,
        @StudenName,
        @branchName,
        @RoleDesignation,
        @Fees,
        @AdmissionDate,
        @IsPayment,
        @IsActive
    );
END;
GO

-- %% [markdown]
-- # [dbo].[SP_InsertStudent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_InsertStudent]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_InsertStudent]
    @Student_fisrt_Name VARCHAR(255),
    @Student_Last_Name VARCHAR(255),
    @Student_Email VARCHAR(255),
    @Student_Phone VARCHAR(20),
    @Student_Session VARCHAR(255),
    @created_date DATETIME,
    @Is_active BIT,
    @Is_Deleted BIT
AS
BEGIN
    INSERT INTO student_master (
        Student_fisrt_Name,
        Student_Last_Name,
        Student_Email,
        Student_Phone,
        Student_Session,
        created_date,
        Is_active,
        Is_Deleted
    )
    VALUES (
        @Student_fisrt_Name,
        @Student_Last_Name,
        @Student_Email,
        @Student_Phone,
        @Student_Session,
        @created_date,
        @Is_active,
        @Is_Deleted
    );
END;



--<----------------------------------------------------------------------------->

CREATE TABLE college_admission_master (
    collage_id INT PRIMARY KEY,
    clg_name VARCHAR(255) NOT NULL,
    session VARCHAR(10) NOT NULL,
    admission_date DATETIME,
    collage_fees DECIMAL(10, 2),
    clg_payment BIT,
    is_active BIT,
    created_date DATETIME DEFAULT GETDATE(),
    student_id INT FOREIGN KEY REFERENCES student_master(student_id),
    role_id INT FOREIGN KEY REFERENCES Role_master(Role_id),
    department_id INT FOREIGN KEY REFERENCES department_master(branch_id)
);
GO

-- %% [markdown]
-- # [dbo].[Sp_update_Department_List]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_update_Department_List]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[Sp_update_Department_List]
    @Branch_id INT,
    @Branch_name VARCHAR(255),
    @Hod_name VARCHAR(255),
    @created_date DATE,
    @Is_active BIT
AS
BEGIN
    UPDATE department_master
    SET
        Branch_name = @Branch_name,
        Hod_name = @Hod_name,
        [created_date] = @created_date,
        [Is_active] = @Is_active
    WHERE
        Branch_id = @Branch_id;
END;
GO

-- %% [markdown]
-- # [dbo].[Sp_update_Role_List]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_update_Role_List]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[Sp_update_Role_List]
    @Role_id INT,
    @Role_name VARCHAR(255),
    @Role_designation VARCHAR(255),
    @created_date DATE,
    @Is_active BIT
AS
BEGIN
    UPDATE Role_master
    SET
        [Role_name] = @Role_name,
        [Role_designation] = @Role_designation,
        [created_date] = @created_date,
        [Is_active] = @Is_active
    WHERE
        Role_id = @Role_id;
END;
GO

-- %% [markdown]
-- # [dbo].[Sp_update_Student_List]

-- %%
/****** Object:  StoredProcedure [dbo].[Sp_update_Student_List]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[Sp_update_Student_List]
    @Student_id INT,
    @Student_fisrt_Name VARCHAR(255),
    @Student_Last_Name VARCHAR(255),
    @Student_Email VARCHAR(255),
    @Student_Phone VARCHAR(20),
    @Student_Session VARCHAR(255),
    @created_date DATETIME,
    @Is_active BIT,
    @Is_Deleted BIT
AS
BEGIN
    UPDATE [student_master]
    SET
        [Student_fisrt_Name] = @Student_fisrt_Name,
        [Student_Last_Name] = @Student_Last_Name,
        [Student_Email] = @Student_Email,
        [Student_Phone] = @Student_Phone,
        [Student_Session] = @Student_Session,
        [created_date] = @created_date,
        [Is_active] = @Is_active,
        [Is_Deleted] = @Is_Deleted
    WHERE
        [Student_id] = @Student_id;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_UpdateCollegeDetails_by_Id]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdateCollegeDetails_by_Id]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_UpdateCollegeDetails_by_Id]
   @clg_id INT,
   @collegeName VARCHAR(50),
   @StudenName INT,
   @branchName INT,
   @RoleDesignation INT,
   @fees DECIMAL(18, 2),
   @AddmissionDate DATETIME,
   @Is_Payment BIT,
   @Is_active BIT
AS
BEGIN
   UPDATE College_Master
   SET
      collegeName = @collegeName,
      StudenName = @StudenName,
      branchName = @branchName,
      RoleDesignation = @RoleDesignation,
      fees = @fees,
      AddmissionDate = @AddmissionDate,
      Is_Payment = @Is_Payment,
      Is_active = @Is_active
   WHERE
      clg_id = @clg_id;
END;
GO

-- %% [markdown]
-- # [dbo].[ValidateLogin]

-- %%
/****** Object:  StoredProcedure [dbo].[ValidateLogin]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ValidateLogin]
    @emailId NVARCHAR(255),
    @decryptedPassword NVARCHAR(50)
AS
BEGIN
    IF EXISTS (
        SELECT 1
        FROM tbl_SignUp
        WHERE emailId = @emailId
        AND decryptedPassword = @decryptedPassword
    )
    BEGIN
        SELECT
            su.id,
            su.name,
            su.emailId
        FROM tbl_SignUp su
        WHERE su.emailId = @emailId
            AND su.decryptedPassword = @decryptedPassword;
    END
END;
GO

-- %% [markdown]
-- # [dbo].[ValidateLoginUser]

-- %%
/****** Object:  StoredProcedure [dbo].[ValidateLoginUser]    Script Date: 13-12-2023 11:31:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[ValidateLoginUser]
    @emailId NVARCHAR(255),
    @decryptedPassword NVARCHAR(50),
    @name NVARCHAR(255) OUTPUT
AS
BEGIN
    IF EXISTS (
        SELECT 1
        FROM tbl_SignUp
        WHERE emailId = @emailId
        AND decryptedPassword = @decryptedPassword
        AND name = @name
    )
    BEGIN
        SELECT
            su.id,
            su.name,
            su.emailId
        FROM tbl_SignUp su
        WHERE su.emailId = @emailId
            AND su.decryptedPassword = @decryptedPassword
            AND su.name = @name;

        -- Set the @name parameter value
        SET @name = (SELECT su.name FROM tbl_SignUp su WHERE su.emailId = @emailId AND su.decryptedPassword = @decryptedPassword AND su.name = @name);
    END
END;
GO
